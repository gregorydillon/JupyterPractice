# %% [markdown]
# Question to answer, geographically, how do the locations of encampments compare to the reports for behavior

# %% [markdown]
# # San Francisco Mattresses

# %% [markdown]
# Import Libraries & get url

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Set Display Column with wider so no problem with Media URL series

# %%
pd.options.display.max_colwidth=115

# %% [markdown]
# ## Setup to display images - NOT working

# %%
from IPython.display import Image
from IPython.core.display import HTML 
from IPython.core.display import Image, display

# %% [markdown]
# ### get url

# %%
url = 'https://data.sfgov.org/resource/3434-6x5u.csv'

# %%
hl = pd.read_csv(url)

# %%
hl.head(1)
# Out:
#     CaseID                  Opened Closed                 Updated Status  \
# 0  6567828  11/26/2016 08:39:37 PM    NaN  11/26/2016 08:39:37 PM   Open
#
#    Responsible Agency                      Category Request Type  \
# 0  Recology_Abandoned  Street and Sidewalk Cleaning  Bulky Items
#
#   Request Details                                      Address  \
# 0        Mattress  2700 VAN NESS AVE, SAN FRANCISCO, CA, 94109
#
#    Supervisor District  Neighborhood                                 Point  \
# 0                  2.0  Russian Hill  (37.800685005499, -122.424156081216)
#
#     Source Media URL
# 0  Open311       NaN

# %%
hl['Opened'] = pd.to_datetime(hl['Opened'])

# %%
hl['Closed'] = pd.to_datetime(hl['Closed'])

# %%
hl['Updated'] = pd.to_datetime(hl['Updated'])

# %%
hl.tail()
# Out:
#       CaseID              Opened              Closed             Updated  \
# 995  6445986 2016-10-21 12:49:41 2016-10-21 14:02:20 2016-10-21 14:02:20
# 996  6445977 2016-10-21 12:48:03 2016-10-21 14:17:02 2016-10-21 14:17:02
# 997  6445696 2016-10-21 11:48:02 2016-10-21 13:52:22 2016-10-21 13:52:22
# 998  6445617 2016-10-21 11:35:11 2016-10-21 15:07:07 2016-10-21 15:07:07
# 999  6445567 2016-10-21 11:26:17 2016-10-21 14:02:08 2016-10-21 14:02:08
#
#      Status  Responsible Agency                      Category Request Type  \
# 995  Closed  Recology_Abandoned  Street and Sidewalk Cleaning  Bulky Items
# 996  Closed  Recology_Abandoned  Street and Sidewalk Cleaning  Bulky Items
# 997  Closed  Recology_Abandoned  Street and Sidewalk Cleaning  Bulky Items
# 998  Closed  Recology_Abandoned  Street and Sidewalk Cleaning  Bulky Items
# 999  Closed  Recology_Abandoned  Street and Sidewalk Cleaning  Bulky Items
#
#     Request Details                                      Address  \
# ...

# %%
hl.Opened.dt.day.value_counts().sort_index().plot()

# %%
hl.Opened.dt.day.value_counts().sort_index().plot()

# %%
hl.Closed.dt.day.value_counts().sort_index().plot()

# %%
hl.Opened.dt.weekday_name.value_counts().plot()

# %%
hl.columns
# Out:
# Index(['CaseID', 'Opened', 'Closed', 'Updated', 'Status', 'Responsible Agency',
#        'Category', 'Request Type', 'Request Details', 'Address',
#        'Supervisor District', 'Neighborhood', 'Point', 'Source', 'Media URL'],
#       dtype='object')

# %%
hl['Supervisor District'].value_counts()
# Out:
#  6.0     202
#  9.0     169
#  5.0     135
#  3.0     117
#  10.0    100
#  8.0      72
#  11.0     65
#  2.0      52
#  1.0      46
#  4.0      23
#  7.0      13
# -1.0       2
# Name: Supervisor District, dtype: int64

# %%
hl.Neighborhood.value_counts()
# Out:
# Mission                         118
# Tenderloin                       91
# South of Market                  77
# Nob Hill                         38
# 21   6564457 2016-11-25 11:23:35 2016-11-25 11:56:57 2016-11-25 11:56:57
# 58   6558389 2016-11-22 21:05:43 2016-11-23 09:40:14 2016-11-23 09:40:14
# 62   6557681 2016-11-22 15:40:45 2016-11-22 16:19:08 2016-11-22 16:19:08
# 78   6555342 2016-11-22 08:43:15 2016-11-22 11:19:04 2016-11-22 11:19:04
# 82   6554958 2016-11-22 06:08:44 2016-11-22 10:32:33 2016-11-22 10:32:33
# 89   6553680 2016-11-21 15:19:27 2016-11-21 17:42:07 2016-11-21 17:42:07
# 110  6551175 2016-11-21 08:34:04 2016-11-21 10:02:27 2016-11-21 10:02:27
# 134  6545915 2016-11-18 15:50:09 2016-11-18 16:18:05 2016-11-18 16:18:05
# ...

# %%
hl[hl['Media URL'].notnull() ]
# Out:
#       CaseID              Opened              Closed             Updated  \
# 2    6567374 2016-11-26 15:13:51 2016-11-26 17:39:01 2016-11-26 17:39:01
# 5    6566697 2016-11-26 10:38:02 2016-11-26 12:39:34 2016-11-26 12:39:34
# 7    6566529 2016-11-26 09:04:17 2016-11-26 10:07:52 2016-11-26 10:07:52
# 12   6566113 2016-11-25 21:10:56 2016-11-26 12:39:22 2016-11-26 12:39:22
# 19   6564569 2016-11-25 12:03:31 2016-11-25 13:01:04 2016-11-25 13:01:04
# 20   6564566 2016-11-25 12:01:58 2016-11-25 13:01:02 2016-11-25 13:01:02
# 26   6563381 2016-11-24 20:26:08 2016-11-25 10:36:18 2016-11-25 10:36:18
# 27   6563187 2016-11-24 16:40:01 2016-11-25 10:36:13 2016-11-25 10:36:13
# 28   6563183 2016-11-24 16:37:36 2016-11-25 10:36:10 2016-11-25 10:36:10
# 30   6563091 2016-11-24 15:24:08 2016-11-24 16:12:12 2016-11-24 16:12:12
# 31   6563037 2016-11-24 14:41:25 2016-11-24 15:27:04 2016-11-24 15:27:04
# 32   6563019 2016-11-24 14:31:40 2016-11-24 14:57:05 2016-11-24 14:57:05
# ...

# %%
hl_images = hl[hl['Media URL'].notnull() ]['Media URL']

# %%
hl_images.tail(1)
# Out:
# 999    http://mobile311.sfgov.org/media/san_francisco/report/photos/580a5db9df8621d231679496/photo_20161021_112558.jpg
# Name: Media URL, dtype: object

# %%
imgURL = hl_images.tail(1)

# %%
imgURL
# Out:
# 999    http://mobile311.sfgov.org/media/san_francisco/report/photos/580a5db9df8621d231679496/photo_20161021_112558.jpg
# Name: Media URL, dtype: object

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= imgURL)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-7d87e3b062e8> in <module>()
#       1 from IPython.display import Image
#       2 from IPython.core.display import HTML
# ----> 3 Image(url= imgURL)
#
# /opt/conda/lib/python3.5/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     713             ext = self._find_ext(filename)
#     714         elif url is not None:
# --> 715             ext = self._find_ext(url)
#     716         elif data is None:
#     717             raise ValueError("No image data found. Expecting filename, url, or data.")
#
# /opt/conda/lib/python3.5/site-packages/IPython/core/display.py in _find_ext(self, s)
#     822
#     823     def _find_ext(self, s):
# --> 824         return unicode_type(s.split('.')[-1].lower())
#     825
# ...

# %%
import geocoder

# %%
hl.head(2)

# %%
addr =hl.Address[0]

# %%
addr

# %%
g = geocoder.google(addr)

# %%
g.wkt
