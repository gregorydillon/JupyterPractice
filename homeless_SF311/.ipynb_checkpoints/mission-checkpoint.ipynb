# %% [markdown]
# Question to answer, geographically, how do the locations of encampments compare to the reports for behavior

# %% [markdown]
# The source of the information is from the San Francisco Open Data Portal
# On that portal, I've created a dataset of Encampments
# https://data.sfgov.org/profile/Gregory/xm4t-k5h4?q=encampment&sortBy=relevance&utf8=%E2%9C%93

# %% [markdown]
# # San Francisco Homeless with Video

# %% [markdown]
# Import Libraries & get url

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Get yesterday variable in bash and format it for url

# %%
#date format 'year-mm-dd'
# date -d "2 weeks ago"

yesterday = !date -d "yesterday 13:00 " '+%Y-%m-%d'

twoDaysAgo = !date -d "2 days ago 13:00 " '+%Y-%m-%d'
oneWeekAgo = !date -d "1 week ago 13:00 " '+%Y-%m-%d'
fourWeeksAgo = !date -d "4 week ago 13:00 " '+%Y-%m-%d'

beginDate = fourWeeksAgo
print(yesterday, twoDaysAgo, oneWeekAgo)
print(beginDate)
startdate = str(beginDate)[1:-1]
print(startdate)


#hard code option
#startdate = "'2016-12-09'"
# Out:
# ['2016-12-20'] ['2016-12-19'] ['2016-12-14']
# ['2016-11-23']
# '2016-11-23'

# %% [markdown]
# ### get url

# %%
#url = 'https://data.sfgov.org/resource/gbya-e2d3.csv' // homeless
url = 'https://data.sfgov.org/resource/gbya-e2d3.csv'
#url = 'https://data.sfgov.org/resource/rme2-xgvs.csv'// graffiti

#  mission homeless https://data.sfgov.org/resource/7rca-bkvr.json
url = 'https://data.sfgov.org/resource/7rca-bkvr.csv'


# mission encampment   https://data.sfgov.org/resource/594p-sp4v.json
url2 = 'https://data.sfgov.org/resource/594p-sp4v.csv'

modify= "?$where=opened"
operator = '>='
#date format 'year-mm-dd'


url = url + modify + operator + str(startdate)
print(url)

url2 = url2 + modify + operator + str(startdate)
print(url2)
# Out:
# https://data.sfgov.org/resource/7rca-bkvr.csv?$where=opened>='2016-11-23'
# https://data.sfgov.org/resource/594p-sp4v.csv?$where=opened>='2016-11-23'

# %%
df = pd.read_csv(url)

print df.shape
df2 = pd.read_csv(url2)
print df2.shape
df =  pd.concat([df,df2])
# Out:
#   File "<ipython-input-59-63c92a13cb58>", line 3
#     print df.shape()
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Set Display Column with wider so no problem with Media URL series

# %%
pd.options.display.max_colwidth=115

# %% [markdown]
# ## Setup to display images - working, work to do

# %%
from IPython.display import Image
from IPython.core.display import HTML 
from IPython.core.display import Image, display

# %% [markdown]
# ## create data frame

# %%
df = pd.read_csv(url)

# %%
df.shape
# Out:
# (63, 16)

# %% [markdown]
# #### wow, 5 days > 1000 reports

# %%
df.head(3)
# Out:
#     CaseID                  Opened                  Closed  \
# 0  6647899  12/20/2016 06:25:29 PM  12/20/2016 07:01:23 PM
# 1  6646409  12/20/2016 12:56:13 PM  12/20/2016 02:35:34 PM
# 2  6645086  12/20/2016 08:56:57 AM  12/20/2016 01:05:06 PM
#
#                   Updated  Status  \
# 0  12/20/2016 07:01:23 PM  Closed
# 1  12/20/2016 02:35:34 PM  Closed
# 2  12/20/2016 01:05:06 PM  Closed
#
#                                                                                                          Status Notes  \
# 0                                 Insufficient Information - Insufficient infomation provided for action to be taken.
# 1  Case Resolved - Police Officer responded to request under CAD # 163551927. Individual(s) not found at location ...
# 2  Case Resolved - Police Officer responded to request under CAD # 163550928. Individual(s) not found at location ...
#
#                  Responsible Agency          Category  \
# 0  Police - Homeless Concerns Queue  General Requests
# 1  Police - Homeless Concerns Queue  General Requests
# 2  Police - Homeless Concerns Queue  General Requests
#
#                                                 Request Type  \
# 0   homeless_concerns - homeless_other - request_for_service
# 1  homeless_concerns - wellbeing_check - request_for_service
# 2  homeless_concerns - wellbeing_check - request_for_service
#
#                                              Request Details  \
# 0   homeless_concerns - homeless_other - request_for_service
# 1  homeless_concerns - wellbeing_check - request_for_service
# 2  homeless_concerns - wellbeing_check - request_for_service
#
#                                          Address  Supervisor District  \
# 0         2300 16TH ST, SAN FRANCISCO, CA, 94103                   10
# 1         Intersection of 17TH ST and ALABAMA ST                    9
# 2  Intersection of CLINTON PARK and STEVENSON ST                    9
#
#   Neighborhood                                  Point   Source  Media URL
# 0      Mission   (37.765819504411, -122.409006416036)  Open311        NaN
# 1      Mission  (37.7641932415638, -122.412293308964)  Open311        NaN
# 2      Mission   (37.7693386881199, -122.42147026036)  Open311        NaN

# %%
df['Opened'] = pd.to_datetime(df['Opened'])
df['Closed'] = pd.to_datetime(df['Closed'])
df['Updated'] = pd.to_datetime(df['Updated'])

# %%
df.head(3)
# Out:
#     CaseID              Opened              Closed             Updated  \
# 0  6647899 2016-12-20 18:25:29 2016-12-20 19:01:23 2016-12-20 19:01:23
# 1  6646409 2016-12-20 12:56:13 2016-12-20 14:35:34 2016-12-20 14:35:34
# 2  6645086 2016-12-20 08:56:57 2016-12-20 13:05:06 2016-12-20 13:05:06
#
#    Status  \
# 0  Closed
# 1  Closed
# 2  Closed
#
#                                                                                                          Status Notes  \
# 0                                 Insufficient Information - Insufficient infomation provided for action to be taken.
# 1  Case Resolved - Police Officer responded to request under CAD # 163551927. Individual(s) not found at location ...
# 2  Case Resolved - Police Officer responded to request under CAD # 163550928. Individual(s) not found at location ...
#
#                  Responsible Agency          Category  \
# 0  Police - Homeless Concerns Queue  General Requests
# 1  Police - Homeless Concerns Queue  General Requests
# 2  Police - Homeless Concerns Queue  General Requests
#
#                                                 Request Type  \
# 0   homeless_concerns - homeless_other - request_for_service
# 1  homeless_concerns - wellbeing_check - request_for_service
# 2  homeless_concerns - wellbeing_check - request_for_service
#
#                                              Request Details  \
# 0   homeless_concerns - homeless_other - request_for_service
# 1  homeless_concerns - wellbeing_check - request_for_service
# 2  homeless_concerns - wellbeing_check - request_for_service
#
#                                          Address  Supervisor District  \
# 0         2300 16TH ST, SAN FRANCISCO, CA, 94103                   10
# 1         Intersection of 17TH ST and ALABAMA ST                    9
# 2  Intersection of CLINTON PARK and STEVENSON ST                    9
#
#   Neighborhood                                  Point   Source  Media URL
# 0      Mission   (37.765819504411, -122.409006416036)  Open311        NaN
# 1      Mission  (37.7641932415638, -122.412293308964)  Open311        NaN
# 2      Mission   (37.7693386881199, -122.42147026036)  Open311        NaN

# %%
df.Closed.dt.day.value_counts().sort_index().plot()

# %%
df.Opened.dt.day.value_counts().sort_index().plot()

# %%
df.Closed.dt.weekday.value_counts().sort_index().plot()

# %%
df.columns
# Out:
# Index(['CaseID', 'Opened', 'Closed', 'Updated', 'Status', 'Status Notes',
#        'Responsible Agency', 'Category', 'Request Type', 'Request Details',
#        'Address', 'Supervisor District', 'Neighborhood', 'Point', 'Source',
#        'Media URL'],
#       dtype='object')

# %%
df['Request Details'].value_counts()
# Out:
# homeless_concerns - aggressive_behavior - request_for_service    29
# homeless_concerns - wellbeing_check - request_for_service        21
# homeless_concerns - homeless_other - request_for_service         13
# Name: Request Details, dtype: int64

# %%
df['Supervisor District'].value_counts().sort_index()
# Out:
# 1      1
# 3      6
# 6     24
# 8      6
# 9     13
# 10     9
# Name: Supervisor District, dtype: int64

# %%
df.Neighborhood.value_counts()
# Out:
# South of Market            13
# Mission                    13
# Showplace Square            7
# Mission Bay                 3
# Rincon Hill                 3
# Potrero Hill                2
# Duboce Triangle             2
# Financial District          2
# Castro                      2
# North Beach                 2
# Fisherman's Wharf           1
# Downtown / Union Square     1
# Bernal Heights              1
# Civic Center                1
# Dolores Heights             1
# Produce Market              1
# Dogpatch                    1
# Lower Nob Hill              1
# Outer Richmond              1
# Mission Dolores             1
# Name: Neighborhood, dtype: int64

# %%
df[df.Neighborhood == 'Mission']
# Out:
#      CaseID              Opened Closed             Updated Status  \
# 1   6648274 2016-12-20 23:17:08    NaT 2016-12-20 23:17:08   Open
# 9   6647906 2016-12-20 18:27:42    NaT 2016-12-20 18:32:08   Open
# 10  6647901 2016-12-20 18:25:46    NaT 2016-12-20 18:25:46   Open
# 14  6647675 2016-12-20 16:58:30    NaT 2016-12-20 16:58:30   Open
# 17  6647552 2016-12-20 16:31:22    NaT 2016-12-20 16:31:22   Open
# 20  6646847 2016-12-20 14:28:30    NaT 2016-12-20 14:28:30   Open
# 22  6646765 2016-12-20 14:12:26    NaT 2016-12-20 14:15:00   Open
# 31  6645864 2016-12-20 11:03:55    NaT 2016-12-20 11:03:55   Open
# 37  6645441 2016-12-20 10:03:50    NaT 2016-12-20 10:04:53   Open
# 42  6645082 2016-12-20 08:56:14    NaT 2016-12-20 08:56:14   Open
# 51  6644837 2016-12-20 08:10:07    NaT 2016-12-20 08:12:57   Open
# 53  6644741 2016-12-20 07:26:42    NaT 2016-12-20 07:26:42   Open
# 55  6644648 2016-12-20 06:22:16    NaT 2016-12-20 06:22:16   Open
#
#    Status Notes Responsible Agency                      Category  \
# 1          open      DPW Ops Queue  Street and Sidewalk Cleaning
# 9          open      DPW Ops Queue  Street and Sidewalk Cleaning
# 10         open      DPW Ops Queue  Street and Sidewalk Cleaning
# 14         open      DPW Ops Queue  Street and Sidewalk Cleaning
# 17         open      DPW Ops Queue  Street and Sidewalk Cleaning
# 20         open      DPW Ops Queue  Street and Sidewalk Cleaning
# 22         open      DPW Ops Queue  Street and Sidewalk Cleaning
# 31         open      DPW Ops Queue  Street and Sidewalk Cleaning
# 37         open      DPW Ops Queue  Street and Sidewalk Cleaning
# 42         open      DPW Ops Queue  Street and Sidewalk Cleaning
# 51         open      DPW Ops Queue  Street and Sidewalk Cleaning
# 53         open      DPW Ops Queue  Street and Sidewalk Cleaning
# 55         open      DPW Ops Queue  Street and Sidewalk Cleaning
#
#           Request Type     Request Details  \
# 1   Illegal Encampment  Encampment Cleanup
# 9   Illegal Encampment  Encampment Cleanup
# 10  Illegal Encampment  Encampment Cleanup
# 14  Illegal Encampment  Encampment Cleanup
# 17  Illegal Encampment  Encampment Cleanup
# 20  Illegal Encampment  Encampment Cleanup
# 22  Illegal Encampment  Encampment Cleanup
# 31  Illegal Encampment  Encampment Cleanup
# 37  Illegal Encampment  Encampment Cleanup
# 42  Illegal Encampment  Encampment Cleanup
# 51  Illegal Encampment  Encampment Cleanup
# 53  Illegal Encampment  Encampment Cleanup
# 55  Illegal Encampment  Encampment Cleanup
#
#                                                   Address  \
# 1        471 SOUTH VAN NESS AVE, SAN FRANCISCO, CA, 94103
# 9                  Intersection of 15TH ST and JULIAN AVE
# 10      1500 SOUTH VAN NESS AVE, SAN FRANCISCO, CA, 94110
# 14                 Intersection of 15TH ST and JULIAN AVE
# 17  Intersection of CESAR CHAVEZ ON RAMP and HAMPSHIRE ST
# 20                 2779 16TH ST, SAN FRANCISCO, CA, 94103
# 22                 Intersection of TRAINOR ST and 13TH ST
# 31       490 SOUTH VAN NESS AVE, SAN FRANCISCO, CA, 94103
# 37                 Intersection of FLORIDA ST and 18TH ST
# 42            1441 STEVENSON ST, SAN FRANCISCO, CA, 94103
# 51                    Intersection of 18TH ST and YORK ST
# 53             1941 HARRISON ST, SAN FRANCISCO, CA, 94103
# 55               375 ALABAMA ST, SAN FRANCISCO, CA, 94110
#
#     Supervisor District Neighborhood                                  Point  \
# 1                     9      Mission   (37.765726211258, -122.417357521918)
# 9                     9      Mission  (37.7665993360598, -122.421056485527)
# 10                    9      Mission     (37.7489895689, -122.416097672246)
# 14                    9      Mission  (37.7665993360598, -122.421056485527)
# 17                    9      Mission    (37.748957298479, -122.40648746343)
# 20                    9      Mission   (37.765208516521, -122.414739199641)
# 22                    9      Mission  (37.7695357006967, -122.414494298645)
# 31                    9      Mission   (37.765511320074, -122.417678769023)
# 37                    9      Mission  (37.7617009755953, -122.411090102877)
# 42                    9      Mission   (37.769114888707, -122.421342120267)
# 51                   10      Mission    (37.76181718584, -122.409156844079)
# 53                    9      Mission    (37.76654276882, -122.413051590739)
# 55                    9      Mission   (37.764560121831, -122.412151340269)
#
#               Source  \
# 1            Open311
# 9           Voice In
# 10           Open311
# 14           Open311
# 17           Open311
# 20           Open311
# 22          Voice In
# 31           Open311
# 37          Voice In
# 42           Open311
# 51          Voice In
# 53  Web Self Service
# 55           Open311
#
#                                                                                                           Media URL
# 1                                                                                                               NaN
# 9                                                                                                               NaN
# 10                                                                                                              NaN
# 14  http://mobile311.sfgov.org/media/san_francisco/report/photos/5859d3a83da153f1b6e8509d/photo_20161220_165743.jpg
# 17                 http://mobile311.sfgov.org/media/san_francisco/report/photos/5859cd4e3da153f1b6e84f1d/report.jpg
# 20                                                                                                              NaN
# 22                                                                                                              NaN
# 31                                                                                                              NaN
# 37                                                                                                              NaN
# 42                 http://mobile311.sfgov.org/media/san_francisco/report/photos/5859629b3da153f1b6e83a47/report.jpg
# 51                                                                                                              NaN
# 53                                                                                                              NaN
# 55                 http://mobile311.sfgov.org/media/san_francisco/report/photos/58593e8d3da153f1b6e833e9/report.jpg

# %% [markdown]
# ### Get rid of NaN entries and display images
#
# Need Help  https://youtu.be/2AFGPdNn4FM?t=8m

# %%
#hl_images = df[df['Media URL'].notnull() ]['Media URL']

# %% [markdown]
# ## limit the data frame to just one neighborhood or just one supervisor district

# %%
peskin = df[df['Supervisor District']==3]['Media URL']
peskin = peskin.reset_index(drop=True)
print(peskin[:])
# Out:
# 0    http://mobile311.sfgov.org/media/san_francisco/report/photos/585a2dd53da153f1b6e85774/photo_20161220_231952.jpg
# 1                                                                                                                NaN
# 2                                                                                                                NaN
# 3                                                                                                                NaN
# 4                   http://mobile311.sfgov.org/media/san_francisco/report/photos/58596f7c3da153f1b6e83d95/report.jpg
# 5                                                                                                                NaN
# Name: Media URL, dtype: object

# %%
print(peskin[:])
# Out:
# 0    http://mobile311.sfgov.org/media/san_francisco/report/photos/585a2dd53da153f1b6e85774/photo_20161220_231952.jpg
# 1                                                                                                                NaN
# 2                                                                                                                NaN
# 3                                                                                                                NaN
# 4                   http://mobile311.sfgov.org/media/san_francisco/report/photos/58596f7c3da153f1b6e83d95/report.jpg
# 5                                                                                                                NaN
# Name: Media URL, dtype: object

# %% [markdown]
# # The whole City

# %%
images = df[df['Media URL'].notnull() ]['Media URL']
images = images.reset_index(drop=True)
print(images[:])
# Out:
# 0     http://mobile311.sfgov.org/media/san_francisco/report/photos/585a2dd53da153f1b6e85774/photo_20161220_231952.jpg
# 1                    http://mobile311.sfgov.org/media/san_francisco/report/photos/5859dc463da153f1b6e851c5/report.jpg
# 2                    http://mobile311.sfgov.org/media/san_francisco/report/photos/5859d4a63da153f1b6e850da/report.jpg
# 3     http://mobile311.sfgov.org/media/san_francisco/report/photos/5859d3a83da153f1b6e8509d/photo_20161220_165743.jpg
# 4                    http://mobile311.sfgov.org/media/san_francisco/report/photos/5859ceb63da153f1b6e84f7b/report.jpg
# 5             http://mobile311.sfgov.org/media/san_francisco/report/photos/5859ce0f3da153f1b6e84f4d/1482280456768.jpg
# 6                    http://mobile311.sfgov.org/media/san_francisco/report/photos/5859cd4e3da153f1b6e84f1d/report.jpg
# 7     http://mobile311.sfgov.org/media/san_francisco/report/photos/5859974f3da153f1b6e847d0/photo_20161220_120434.jpg
# 8                    http://mobile311.sfgov.org/media/san_francisco/report/photos/585989db3da153f1b6e845ce/report.jpg
# 9     http://mobile311.sfgov.org/media/san_francisco/report/photos/5859877a3da153f1b6e8456e/photo_20161220_113230.jpg
# 10    http://mobile311.sfgov.org/media/san_francisco/report/photos/5859868c3da153f1b6e84509/photo_20161220_112855.jpg
# 11    http://mobile311.sfgov.org/media/san_francisco/report/photos/58597dbb3da153f1b6e84322/photo_20161220_105048.jpg
# 12                   http://mobile311.sfgov.org/media/san_francisco/report/photos/58596f7c3da153f1b6e83d95/report.jpg
# 13                   http://mobile311.sfgov.org/media/san_francisco/report/photos/585969a93da153f1b6e83c75/report.jpg
# 14    http://mobile311.sfgov.org/media/san_francisco/report/photos/585966f53da153f1b6e83b43/photo_20161220_091359.jpg
# 15                   http://mobile311.sfgov.org/media/san_francisco/report/photos/5859629b3da153f1b6e83a47/report.jpg
# 16                   http://mobile311.sfgov.org/media/san_francisco/report/photos/58595f043da153f1b6e839c7/report.jpg
# 17                   http://mobile311.sfgov.org/media/san_francisco/report/photos/58595cf13da153f1b6e8396f/report.jpg
# 18                   http://mobile311.sfgov.org/media/san_francisco/report/photos/58595cbf3da153f1b6e83954/report.jpg
# 19    http://mobile311.sfgov.org/media/san_francisco/report/photos/58595cb63da153f1b6e8393e/photo_20161220_082955.jpg
# 20    http://mobile311.sfgov.org/media/san_francisco/report/photos/58595b1a3da153f1b6e83896/photo_20161220_082257.jpg
# 21                   http://mobile311.sfgov.org/media/san_francisco/report/photos/58595b0e3da153f1b6e83885/report.jpg
# 22                   http://mobile311.sfgov.org/media/san_francisco/report/photos/58595acc3da153f1b6e83861/report.jpg
# 23                   http://mobile311.sfgov.org/media/san_francisco/report/photos/58594dbd3da153f1b6e835f7/report.jpg
# 24                   http://mobile311.sfgov.org/media/san_francisco/report/photos/58593e8d3da153f1b6e833e9/report.jpg
# 25                   http://mobile311.sfgov.org/media/san_francisco/report/photos/5858fd0e3da153f1b6e8327d/report.jpg
# Name: Media URL, dtype: object

# %%
len(images)
# Out:
# 26

# %%
images[0]
# Out:
# 'http://mobile311.sfgov.org/media/san_francisco/report/photos/585a2dd53da153f1b6e85774/photo_20161220_231952.jpg'

# %%
print(images[2])
Image(images[2])
# Out:
# http://mobile311.sfgov.org/media/san_francisco/report/photos/5859d4a63da153f1b6e850da/report.jpg

# %%
# !pwd
# Out:
# /home/gdillon/JupyterPractice/homeless_SF311

# %%
images[:1000].to_csv("./imagelist.txt", index=False)

# %%
# !yes| bash vidCreate.sh
# Out:
# --2016-12-21 15:30:00--  http://mobile311.sfgov.org/media/san_francisco/report/photos/585a2dd53da153f1b6e85774/photo_20161220_231952.jpg
# Resolving mobile311.sfgov.org (mobile311.sfgov.org)... 54.144.250.241
# Connecting to mobile311.sfgov.org (mobile311.sfgov.org)|54.144.250.241|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 92442 (90K) [image/jpeg]
# Saving to: 'photo_20161220_231952.jpg'
#
# photo_20161220_2319 100%[===================>]  90.28K   585KB/s    in 0.2s
#
# 2016-12-21 15:30:00 (585 KB/s) - 'photo_20161220_231952.jpg' saved [92442/92442]
#
# --2016-12-21 15:30:00--  http://mobile311.sfgov.org/media/san_francisco/report/photos/5859dc463da153f1b6e851c5/report.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 259433 (253K) [image/jpeg]
# Saving to: 'report.jpg'
#
# report.jpg          100%[===================>] 253.35K  --.-KB/s    in 0.08s
#
# 2016-12-21 15:30:00 (3.16 MB/s) - 'report.jpg' saved [259433/259433]
#
# --2016-12-21 15:30:00--  http://mobile311.sfgov.org/media/san_francisco/report/photos/5859d4a63da153f1b6e850da/report.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 254137 (248K) [image/jpeg]
# Saving to: 'report.jpg.1'
#
# report.jpg.1        100%[===================>] 248.18K  --.-KB/s    in 0.04s
#
# 2016-12-21 15:30:01 (5.99 MB/s) - 'report.jpg.1' saved [254137/254137]
#
# --2016-12-21 15:30:01--  http://mobile311.sfgov.org/media/san_francisco/report/photos/5859d3a83da153f1b6e8509d/photo_20161220_165743.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 146763 (143K) [image/jpeg]
# Saving to: 'photo_20161220_165743.jpg'
#
# photo_20161220_1657 100%[===================>] 143.32K  --.-KB/s    in 0.001s
#
# 2016-12-21 15:30:01 (129 MB/s) - 'photo_20161220_165743.jpg' saved [146763/146763]
#
# --2016-12-21 15:30:01--  http://mobile311.sfgov.org/media/san_francisco/report/photos/5859ceb63da153f1b6e84f7b/report.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 159095 (155K) [image/jpeg]
# Saving to: 'report.jpg.2'
#
# report.jpg.2        100%[===================>] 155.37K  --.-KB/s    in 0s
#
# 2016-12-21 15:30:01 (336 MB/s) - 'report.jpg.2' saved [159095/159095]
#
# --2016-12-21 15:30:01--  http://mobile311.sfgov.org/media/san_francisco/report/photos/5859ce0f3da153f1b6e84f4d/1482280456768.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 201078 (196K) [image/jpeg]
# Saving to: '1482280456768.jpg'
#
# 1482280456768.jpg   100%[===================>] 196.37K  --.-KB/s    in 0.002s
#
# 2016-12-21 15:30:01 (94.1 MB/s) - '1482280456768.jpg' saved [201078/201078]
#
# --2016-12-21 15:30:01--  http://mobile311.sfgov.org/media/san_francisco/report/photos/5859cd4e3da153f1b6e84f1d/report.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 277668 (271K) [image/jpeg]
# Saving to: 'report.jpg.3'
#
# report.jpg.3        100%[===================>] 271.16K  --.-KB/s    in 0.002s
#
# 2016-12-21 15:30:01 (148 MB/s) - 'report.jpg.3' saved [277668/277668]
#
# --2016-12-21 15:30:01--  http://mobile311.sfgov.org/media/san_francisco/report/photos/5859974f3da153f1b6e847d0/photo_20161220_120434.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 235839 (230K) [image/jpeg]
# Saving to: 'photo_20161220_120434.jpg'
#
# photo_20161220_1204 100%[===================>] 230.31K  --.-KB/s    in 0.002s
#
# 2016-12-21 15:30:01 (127 MB/s) - 'photo_20161220_120434.jpg' saved [235839/235839]
#
# --2016-12-21 15:30:01--  http://mobile311.sfgov.org/media/san_francisco/report/photos/585989db3da153f1b6e845ce/report.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 235789 (230K) [image/jpeg]
# Saving to: 'report.jpg.4'
#
# report.jpg.4        100%[===================>] 230.26K  --.-KB/s    in 0.001s
#
# 2016-12-21 15:30:01 (173 MB/s) - 'report.jpg.4' saved [235789/235789]
#
# --2016-12-21 15:30:01--  http://mobile311.sfgov.org/media/san_francisco/report/photos/5859877a3da153f1b6e8456e/photo_20161220_113230.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 138832 (136K) [image/jpeg]
# Saving to: 'photo_20161220_113230.jpg'
#
# photo_20161220_1132 100%[===================>] 135.58K  --.-KB/s    in 0s
#
# 2016-12-21 15:30:01 (308 MB/s) - 'photo_20161220_113230.jpg' saved [138832/138832]
#
# --2016-12-21 15:30:01--  http://mobile311.sfgov.org/media/san_francisco/report/photos/5859868c3da153f1b6e84509/photo_20161220_112855.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 173050 (169K) [image/jpeg]
# Saving to: 'photo_20161220_112855.jpg'
#
# photo_20161220_1128 100%[===================>] 168.99K  --.-KB/s    in 0.001s
#
# 2016-12-21 15:30:01 (214 MB/s) - 'photo_20161220_112855.jpg' saved [173050/173050]
#
# --2016-12-21 15:30:01--  http://mobile311.sfgov.org/media/san_francisco/report/photos/58597dbb3da153f1b6e84322/photo_20161220_105048.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 125394 (122K) [image/jpeg]
# Saving to: 'photo_20161220_105048.jpg'
#
# photo_20161220_1050 100%[===================>] 122.46K  --.-KB/s    in 0.001s
#
# 2016-12-21 15:30:01 (209 MB/s) - 'photo_20161220_105048.jpg' saved [125394/125394]
#
# --2016-12-21 15:30:01--  http://mobile311.sfgov.org/media/san_francisco/report/photos/58596f7c3da153f1b6e83d95/report.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 233409 (228K) [image/jpeg]
# Saving to: 'report.jpg.5'
#
# report.jpg.5        100%[===================>] 227.94K  --.-KB/s    in 0.001s
#
# 2016-12-21 15:30:01 (326 MB/s) - 'report.jpg.5' saved [233409/233409]
#
# --2016-12-21 15:30:01--  http://mobile311.sfgov.org/media/san_francisco/report/photos/585969a93da153f1b6e83c75/report.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 213597 (209K) [image/jpeg]
# Saving to: 'report.jpg.6'
#
# report.jpg.6        100%[===================>] 208.59K  --.-KB/s    in 0.001s
#
# 2016-12-21 15:30:01 (220 MB/s) - 'report.jpg.6' saved [213597/213597]
#
# --2016-12-21 15:30:01--  http://mobile311.sfgov.org/media/san_francisco/report/photos/585966f53da153f1b6e83b43/photo_20161220_091359.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 137626 (134K) [image/jpeg]
# Saving to: 'photo_20161220_091359.jpg'
#
# photo_20161220_0913 100%[===================>] 134.40K  --.-KB/s    in 0s
#
# 2016-12-21 15:30:01 (331 MB/s) - 'photo_20161220_091359.jpg' saved [137626/137626]
#
# --2016-12-21 15:30:01--  http://mobile311.sfgov.org/media/san_francisco/report/photos/5859629b3da153f1b6e83a47/report.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 220132 (215K) [image/jpeg]
# Saving to: 'report.jpg.7'
#
# report.jpg.7        100%[===================>] 214.97K  --.-KB/s    in 0.001s
#
# 2016-12-21 15:30:01 (273 MB/s) - 'report.jpg.7' saved [220132/220132]
#
# --2016-12-21 15:30:01--  http://mobile311.sfgov.org/media/san_francisco/report/photos/58595f043da153f1b6e839c7/report.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 124655 (122K) [image/jpeg]
# Saving to: 'report.jpg.8'
#
# report.jpg.8        100%[===================>] 121.73K  --.-KB/s    in 0.001s
#
# 2016-12-21 15:30:01 (97.4 MB/s) - 'report.jpg.8' saved [124655/124655]
#
# --2016-12-21 15:30:01--  http://mobile311.sfgov.org/media/san_francisco/report/photos/58595cf13da153f1b6e8396f/report.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 221008 (216K) [image/jpeg]
# Saving to: 'report.jpg.9'
#
# report.jpg.9        100%[===================>] 215.83K  --.-KB/s    in 0.001s
#
# 2016-12-21 15:30:01 (304 MB/s) - 'report.jpg.9' saved [221008/221008]
#
# --2016-12-21 15:30:01--  http://mobile311.sfgov.org/media/san_francisco/report/photos/58595cbf3da153f1b6e83954/report.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 246615 (241K) [image/jpeg]
# Saving to: 'report.jpg.10'
#
# report.jpg.10       100%[===================>] 240.83K  --.-KB/s    in 0.002s
#
# 2016-12-21 15:30:01 (109 MB/s) - 'report.jpg.10' saved [246615/246615]
#
# --2016-12-21 15:30:01--  http://mobile311.sfgov.org/media/san_francisco/report/photos/58595cb63da153f1b6e8393e/photo_20161220_082955.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 314735 (307K) [image/jpeg]
# Saving to: 'photo_20161220_082955.jpg'
#
# photo_20161220_0829 100%[===================>] 307.36K  --.-KB/s    in 0.001s
#
# 2016-12-21 15:30:01 (211 MB/s) - 'photo_20161220_082955.jpg' saved [314735/314735]
#
# --2016-12-21 15:30:01--  http://mobile311.sfgov.org/media/san_francisco/report/photos/58595b1a3da153f1b6e83896/photo_20161220_082257.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 180939 (177K) [image/jpeg]
# Saving to: 'photo_20161220_082257.jpg'
#
# photo_20161220_0822 100%[===================>] 176.70K  --.-KB/s    in 0.001s
#
# 2016-12-21 15:30:01 (276 MB/s) - 'photo_20161220_082257.jpg' saved [180939/180939]
#
# --2016-12-21 15:30:01--  http://mobile311.sfgov.org/media/san_francisco/report/photos/58595b0e3da153f1b6e83885/report.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 150251 (147K) [image/jpeg]
# Saving to: 'report.jpg.11'
#
# report.jpg.11       100%[===================>] 146.73K  --.-KB/s    in 0.001s
#
# 2016-12-21 15:30:01 (276 MB/s) - 'report.jpg.11' saved [150251/150251]
#
# --2016-12-21 15:30:01--  http://mobile311.sfgov.org/media/san_francisco/report/photos/58595acc3da153f1b6e83861/report.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 296348 (289K) [image/jpeg]
# Saving to: 'report.jpg.12'
#
# report.jpg.12       100%[===================>] 289.40K  --.-KB/s    in 0.001s
#
# 2016-12-21 15:30:01 (240 MB/s) - 'report.jpg.12' saved [296348/296348]
#
# --2016-12-21 15:30:01--  http://mobile311.sfgov.org/media/san_francisco/report/photos/58594dbd3da153f1b6e835f7/report.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 173114 (169K) [image/jpeg]
# Saving to: 'report.jpg.13'
#
# report.jpg.13       100%[===================>] 169.06K  --.-KB/s    in 0.001s
#
# 2016-12-21 15:30:02 (283 MB/s) - 'report.jpg.13' saved [173114/173114]
#
# --2016-12-21 15:30:02--  http://mobile311.sfgov.org/media/san_francisco/report/photos/58593e8d3da153f1b6e833e9/report.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 106802 (104K) [image/jpeg]
# Saving to: 'report.jpg.14'
#
# report.jpg.14       100%[===================>] 104.30K  --.-KB/s    in 0.001s
#
# 2016-12-21 15:30:02 (135 MB/s) - 'report.jpg.14' saved [106802/106802]
#
# --2016-12-21 15:30:02--  http://mobile311.sfgov.org/media/san_francisco/report/photos/5858fd0e3da153f1b6e8327d/report.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 93535 (91K) [image/jpeg]
# Saving to: 'report.jpg.15'
#
# report.jpg.15       100%[===================>]  91.34K  --.-KB/s    in 0s
#
# 2016-12-21 15:30:02 (332 MB/s) - 'report.jpg.15' saved [93535/93535]
#
# FINISHED --2016-12-21 15:30:02--
# Total wall clock time: 1.8s
# Downloaded: 26 files, 4.8M in 0.3s (16.2 MB/s)
# ffmpeg version 2.8.8-0ubuntu0.16.04.1 Copyright (c) 2000-2016 the FFmpeg developers
#   built with gcc 5.4.0 (Ubuntu 5.4.0-6ubuntu1~16.04.2) 20160609
#   configuration: --prefix=/usr --extra-version=0ubuntu0.16.04.1 --build-suffix=-ffmpeg --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --cc=cc --cxx=g++ --enable-gpl --enable-shared --disable-stripping --disable-decoder=libopenjpeg --disable-decoder=libschroedinger --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmodplug --enable-libmp3lame --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librtmp --enable-libschroedinger --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxvid --enable-libzvbi --enable-openal --enable-opengl --enable-x11grab --enable-libdc1394 --enable-libiec61883 --enable-libzmq --enable-frei0r --enable-libx264 --enable-libopencv
#   libavutil      54. 31.100 / 54. 31.100
#   libavcodec     56. 60.100 / 56. 60.100
#   libavformat    56. 40.101 / 56. 40.101
#   libavdevice    56.  4.100 / 56.  4.100
#   libavfilter     5. 40.101 /  5. 40.101
#   libavresample   2.  1.  0 /  2.  1.  0
#   libswscale      3.  1.101 /  3.  1.101
#   libswresample   1.  2.101 /  1.  2.101
#   libpostproc    53.  3.100 / 53.  3.100
# [mjpeg @ 0x2604de0] Changeing bps to 8
# Input #0, image2, from '%04d.jpg':
#   Duration: 00:00:26.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 920x920 [SAR 1:1 DAR 1:1], 1 fps, 1 tbr, 1 tbn, 1 tbc
# File '../video.gif' already exists. Overwrite ? [y/N] [swscaler @ 0x26372a0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x26372a0] No accelerated colorspace conversion found from yuv420p to bgr8.
# Output #0, gif, to '../video.gif':
#   Metadata:
#     encoder         : Lavf56.40.101
#     Stream #0:0: Video: gif, bgr8, 920x920 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 1 fps, 100 tbn, 1 tbc
#     Metadata:
#       encoder         : Lavc56.60.100 gif
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> gif (native))
# Press [q] to stop, [?] for help
# Input stream #0:0 frame changed from size:920x920 fmt:yuvj420p to size:1152x1536 fmt:yuvj420p
# [swscaler @ 0x26372a0] deprecated pixel format used, make sure you did set range correctly
# Input stream #0:0 frame changed from size:1152x1536 fmt:yuvj420p to size:864x1536 fmt:yuvj420p
# [swscaler @ 0x26372a0] deprecated pixel format used, make sure you did set range correctly
# Input stream #0:0 frame changed from size:864x1536 fmt:yuvj420p to size:1536x864 fmt:yuvj420p
# [swscaler @ 0x26372a0] deprecated pixel format used, make sure you did set range correctly
# Input stream #0:0 frame changed from size:1536x864 fmt:yuvj420p to size:864x1536 fmt:yuvj420p
# [swscaler @ 0x2618800] deprecated pixel format used, make sure you did set range correctly
# Input stream #0:0 frame changed from size:864x1536 fmt:yuvj420p to size:1140x1536 fmt:yuvj420p
# [swscaler @ 0x2637340] deprecated pixel format used, make sure you did set range correctly
# Input stream #0:0 frame changed from size:1140x1536 fmt:yuvj420p to size:1536x1152 fmt:yuvj420p
# [swscaler @ 0x2636b20] deprecated pixel format used, make sure you did set range correctly
# Input stream #0:0 frame changed from size:1536x1152 fmt:yuvj420p to size:1152x1536 fmt:yuvj420p
# [swscaler @ 0x2618800] deprecated pixel format used, make sure you did set range correctly
# Input stream #0:0 frame changed from size:1152x1536 fmt:yuvj420p to size:864x1536 fmt:yuvj420p
# [swscaler @ 0x2618800] deprecated pixel format used, make sure you did set range correctly
# Input stream #0:0 frame changed from size:864x1536 fmt:yuvj420p to size:865x1536 fmt:yuvj420p
# [swscaler @ 0x26361a0] deprecated pixel format used, make sure you did set range correctly
# Input stream #0:0 frame changed from size:865x1536 fmt:yuvj420p to size:1536x1152 fmt:yuvj420p
# [swscaler @ 0x2618800] deprecated pixel format used, make sure you did set range correctly
# Input stream #0:0 frame changed from size:1536x1152 fmt:yuvj420p to size:1152x1536 fmt:yuvj420p
# [swscaler @ 0x2618800] deprecated pixel format used, make sure you did set range correctly
# Input stream #0:0 frame changed from size:1152x1536 fmt:yuvj420p to size:1536x1152 fmt:yuvj420p
# [swscaler @ 0x2618800] deprecated pixel format used, make sure you did set range correctly
# Input stream #0:0 frame changed from size:1536x1152 fmt:yuvj420p to size:1536x1154 fmt:yuvj420p
# [swscaler @ 0x2a8ce00] deprecated pixel format used, make sure you did set range correctly
# Input stream #0:0 frame changed from size:1536x1154 fmt:yuvj420p to size:1152x1536 fmt:yuvj420p
# [swscaler @ 0x262c6c0] deprecated pixel format used, make sure you did set range correctly
# frame=   26 fps=8.3 q=-0.0 Lsize=    7161kB time=00:00:26.00 bitrate=2256.1kbits/s
# video:7160kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.013763%
# yes: standard output: Broken pipe

# %%
# !ls -la
