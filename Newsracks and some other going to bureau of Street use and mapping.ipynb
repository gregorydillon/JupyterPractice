# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://data.sfgov.org/resource/xqpg-cqy8.csv')

# %%
df.head()
# Out:
#     CaseID                  Opened Closed                 Updated Status  \
# 0  6550554  11/21/2016 12:00:33 AM    NaN  11/21/2016 12:01:37 AM   Open
# 1  6550176  11/20/2016 05:18:42 PM    NaN  11/20/2016 05:20:09 PM   Open
# 2  6550094  11/20/2016 04:41:55 PM    NaN  11/20/2016 04:42:46 PM   Open
# 3  6550068  11/20/2016 04:34:34 PM    NaN  11/20/2016 04:36:04 PM   Open
# 4  6549452  11/20/2016 12:36:18 PM    NaN  11/20/2016 12:36:18 PM   Open
#
#   Status Notes             Responsible Agency                      Category  \
# 0         Open  Clear Channel - Transit Queue      Graffiti Public Property
# 1         Open  Clear Channel - Transit Queue              Damaged Property
# 2         Open  Clear Channel - Transit Queue              Damaged Property
# 3         Open  Clear Channel - Transit Queue              Damaged Property
# 4         Open  Clear Channel - Transit Queue  Street and Sidewalk Cleaning
#
#                                  Request Type  \
# ...

# %%
df.count()
# Out:
# CaseID                 1000
# Opened                 1000
# Closed                  971
# Updated                1000
# Status                 1000
# Status Notes           1000
# Responsible Agency     1000
# Category               1000
# Request Type           1000
# Request Details         988
# Address                1000
# Supervisor District     987
# Neighborhood            957
# Point                   983
# Source                 1000
# Media URL               519
# dtype: int64

# %%
df['Neighborhood'].value_counts()
# Out:
# Mission                         121
# South of Market                  96
# Outer Richmond                   74
# Civic Center                     57
# Duboce Triangle                  54
# Mission Dolores                  46
# Tenderloin                       45
# Chinatown                        26
# Dolores Heights                  23
# Mission Bay                      20
# Inner Richmond                   17
# Downtown / Union Square          17
# West Portal                      17
# Outer Sunset                     13
# Lower Haight                     13
# Financial District               12
# Golden Gate Park                 11
# Alamo Square                     11
# Portola                          11
# Polk Gulch                       10
# Bayview                           9
# Inner Sunset                      9
# Western Addition                  9
# Dogpatch                          8
# Crocker Amazon                    8
# Excelsior                         8
# ...
