# %% [markdown]
# Question to answer, geographically, how do the locations of encampments compare to the reports for behavior

# %% [markdown]
# The source of the information is from the San Francisco Open Data Portal
# On that portal, I've created a dataset of Encampments
# https://data.sfgov.org/profile/Gregory/xm4t-k5h4?q=encampment&sortBy=relevance&utf8=%E2%9C%93

# %% [markdown]
# # San Francisco Homeless with Video

# %% [markdown]
# Import Libraries & get url

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Get yesterday variable in bash and format it for url

# %%
yesterday = !date -d "yesterday 13:00 " '+%Y-%m-%d'
yesterday = str(yesterday)[1:-1]
print(type(yesterday))
print(yesterday)
# Out:
# <class 'str'>
# '2016-12-11'

# %% [markdown]
# ### get url

# %%
#url = 'https://data.sfgov.org/resource/gbya-e2d3.csv' // homeless
#url = 'https://data.sfgov.org/resource/gbya-e2d3.csv'

#url = 'https://data.sfgov.org/resource/rme2-xgvs.csv' // graffiti
#url = 'https://data.sfgov.org/resource/rme2-xgvs.csv'

#url = 'https://data.sfgov.org/resource/3434-6x5u.csv' //mattress
url = 'https://data.sfgov.org/resource/3434-6x5u.csv' 
modify= "?$where=opened"
operator = '>='
#date format 'year-mm-dd'
startdate = "'2016-12-01'"
#startdate = yesterday
url = url + modify + operator + str(startdate)
print(url)
# Out:
# https://data.sfgov.org/resource/3434-6x5u.csv?$where=opened>='2016-12-01'

# %%
#df1 = pd.read_csv(url)
#df2 = pd.read_csv(url2)
#df =  pd.concat([df1,df2])

# %% [markdown]
# ## Set Display Column with wider so no problem with Media URL series

# %%
pd.options.display.max_colwidth=115

# %% [markdown]
# ## Setup to display images - working, work to do

# %%
from IPython.display import Image
from IPython.core.display import HTML 
from IPython.core.display import Image, display

# %% [markdown]
# ## create data frame

# %%
df = pd.read_csv(url)

# %%
df.shape
# Out:
# (286, 15)

# %% [markdown]
# #### wow, 5 days > 1000 reports

# %%
df.head(3)
# Out:
#     CaseID                  Opened                  Closed  \
# 0  6615544  12/10/2016 07:00:55 PM                     NaN
# 1  6615050  12/10/2016 03:42:02 PM  12/10/2016 05:48:20 PM
# 2  6614596  12/10/2016 01:01:52 PM  12/10/2016 02:33:02 PM
#
#                   Updated  Status  Responsible Agency  \
# 0  12/10/2016 07:02:31 PM    Open  Recology_Abandoned
# 1  12/10/2016 05:48:20 PM  Closed  Recology_Abandoned
# 2  12/10/2016 02:33:02 PM  Closed  Recology_Abandoned
#
#                        Category Request Type Request Details  \
# 0  Street and Sidewalk Cleaning  Bulky Items        Mattress
# 1  Street and Sidewalk Cleaning  Bulky Items        Mattress
# 2  Street and Sidewalk Cleaning  Bulky Items        Mattress
#
#                                        Address  Supervisor District  \
# 0          Intersection of HYDE ST and POST ST                  6.0
# 1  Intersection of LEAVENWORTH ST and GEARY ST                  6.0
# 2       Intersection of 19TH ST and OAKWOOD ST                  8.0
#
#       Neighborhood                                  Point    Source Media URL
# 0   Lower Nob Hill  (37.7872450858839, -122.416638564247)  Voice In       NaN
# 1       Tenderloin   (37.7865197281275, -122.41480651369)  Voice In       NaN
# 2  Mission Dolores   (37.7598935230725, -122.42486308879)  Voice In       NaN

# %%
df['Opened'] = pd.to_datetime(df['Opened'])
df['Closed'] = pd.to_datetime(df['Closed'])
df['Updated'] = pd.to_datetime(df['Updated'])

# %%
df.head(3)
# Out:
#     CaseID              Opened              Closed             Updated  \
# 0  6615544 2016-12-10 19:00:55                 NaT 2016-12-10 19:02:31
# 1  6615050 2016-12-10 15:42:02 2016-12-10 17:48:20 2016-12-10 17:48:20
# 2  6614596 2016-12-10 13:01:52 2016-12-10 14:33:02 2016-12-10 14:33:02
#
#    Status  Responsible Agency                      Category Request Type  \
# 0    Open  Recology_Abandoned  Street and Sidewalk Cleaning  Bulky Items
# 1  Closed  Recology_Abandoned  Street and Sidewalk Cleaning  Bulky Items
# 2  Closed  Recology_Abandoned  Street and Sidewalk Cleaning  Bulky Items
#
#   Request Details                                      Address  \
# 0        Mattress          Intersection of HYDE ST and POST ST
# 1        Mattress  Intersection of LEAVENWORTH ST and GEARY ST
# 2        Mattress       Intersection of 19TH ST and OAKWOOD ST
#
#    Supervisor District     Neighborhood  \
# 0                  6.0   Lower Nob Hill
# 1                  6.0       Tenderloin
# 2                  8.0  Mission Dolores
#
#                                    Point    Source Media URL
# 0  (37.7872450858839, -122.416638564247)  Voice In       NaN
# 1   (37.7865197281275, -122.41480651369)  Voice In       NaN
# 2   (37.7598935230725, -122.42486308879)  Voice In       NaN

# %%
df.Closed.dt.day.value_counts().sort_index().plot()

# %%
df.Opened.dt.day.value_counts().sort_index().plot()

# %%
df.Closed.dt.weekday.value_counts().sort_index().plot()

# %%
df.columns
# Out:
# Index(['CaseID', 'Opened', 'Closed', 'Updated', 'Status', 'Responsible Agency',
#        'Category', 'Request Type', 'Request Details', 'Address',
#        'Supervisor District', 'Neighborhood', 'Point', 'Source', 'Media URL'],
#       dtype='object')

# %%
df['Request Details'].value_counts()
# Out:
# Mattress    286
# Name: Request Details, dtype: int64

# %%
df['Supervisor District'].value_counts().sort_index()
# Out:
# 1.0     19
# 2.0     24
# 3.0     31
# 4.0     10
# 5.0     39
# 6.0     46
# 7.0      9
# 8.0     25
# 9.0     31
# 10.0    22
# 11.0    28
# Name: Supervisor District, dtype: int64

# %%
df.Neighborhood.value_counts()
# Out:
# Tenderloin                      24
# Mission                         22
# South of Market                 14
# Nob Hill                        11
# Excelsior                       10
# Bernal Heights                  10
# Lower Nob Hill                   9
# Inner Richmond                   7
# Visitacion Valley                7
# Pacific Heights                  7
# Outer Sunset                     7
# Outer Richmond                   7
# Lower Pacific Heights            6
# Haight Ashbury                   6
# Oceanview                        6
# Panhandle                        6
# Cathedral Hill                   5
# Mission Dolores                  5
# Russian Hill                     5
# Downtown / Union Square          4
# Ingleside                        4
# Alamo Square                     4
# Potrero Hill                     4
# Cayuga                           4
# Marina                           4
# Crocker Amazon                   4
# Castro                           3
# Bayview                          3
# Laurel Heights / Jordan Park     3
# Western Addition                 3
#                                 ..
# Noe Valley                       2
# Inner Sunset                     2
# Silver Terrace                   2
# Duboce Triangle                  2
# Lower Haight                     2
# Polk Gulch                       2
# Lone Mountain                    2
# Chinatown                        2
# North Beach                      2
# Cow Hollow                       2
# Sunnyside                        1
# Holly Park                       1
# Lake Street                      1
# Golden Gate Heights              1
# Mission Terrace                  1
# Laguna Honda                     1
# Ashbury Heights                  1
# Cole Valley                      1
# Merced Heights                   1
# Telegraph Hill                   1
# Mission Bay                      1
# Upper Market                     1
# Dolores Heights                  1
# Mint Hill                        1
# Portola                          1
# Parkside                         1
# Rincon Hill                      1
# Golden Gate Park                 1
# Hayes Valley                     1
# Seacliff                         1
# Name: Neighborhood, dtype: int64

# %%
#df[df.Neighborhood == 'Mission']
df = df[df.Neighborhood == 'Mission']

# %% [markdown]
# ### Get rid of NaN entries and display images
#
# Need Help  https://youtu.be/2AFGPdNn4FM?t=8m

# %%
#hl_images = df[df['Media URL'].notnull() ]['Media URL']

# %%
images = df[df['Media URL'].notnull() ]['Media URL']
images = images.reset_index(drop=True)
print(images[:])
# Out:
# 0     http://mobile311.sfgov.org/media/san_francisco/report/photos/584b2dcb3da19793c74c6b3c/photo_20161209_141838.jpg
# 1               http://mobile311.sfgov.org/media/san_francisco/report/photos/5849eedd3da19793c74c4e09/IMAG1420_1_.jpg
# 2                    http://mobile311.sfgov.org/media/san_francisco/report/photos/58485b9b3da19793c74c27e4/report.jpg
# 3     http://mobile311.sfgov.org/media/san_francisco/report/photos/5846e6f53da19793c74bef7f/photo_20161206_082645.jpg
# 4                  http://mobile311.sfgov.org/media/san_francisco/report/photos/5846d9cd3da19793c74beca2/IMG_1624.JPG
# 5                    http://mobile311.sfgov.org/media/san_francisco/report/photos/5844b3de3da19793c74baa88/report.jpg
# 6     http://mobile311.sfgov.org/media/san_francisco/report/photos/584494013da19793c74ba596/photo_20161204_140903.jpg
# 7                    http://mobile311.sfgov.org/media/san_francisco/report/photos/584373593da19793c74b9218/report.jpg
# 8                    http://mobile311.sfgov.org/media/san_francisco/report/photos/5840ee343da18eff3daafe17/report.jpg
# 9     http://mobile311.sfgov.org/media/san_francisco/report/photos/5840c2ec3da18eff3daafa77/photo_20161201_164006.jpg
# 10                   http://mobile311.sfgov.org/media/san_francisco/report/photos/5840400a3da18eff3daadd7b/report.jpg
# 11    http://mobile311.sfgov.org/media/san_francisco/report/photos/58403a353da18eff3daadbfb/photo_20161201_065644.jpg
# 12            http://mobile311.sfgov.org/media/san_francisco/report/photos/584035293da18eff3daadb81/1480602902016.jpg
# Name: Media URL, dtype: object

# %%
len(images)
# Out:
# 13

# %%
images[0]
# Out:
# 'http://mobile311.sfgov.org/media/san_francisco/report/photos/584b2dcb3da19793c74c6b3c/photo_20161209_141838.jpg'

# %%
print(images[4])
Image(images[4])
# Out:
# http://mobile311.sfgov.org/media/san_francisco/report/photos/5846d9cd3da19793c74beca2/IMG_1624.JPG

# %%
# !pwd
# Out:
# /home/gdillon/JupyterPractice/homeless_311

# %%
images[:180].to_csv("./imagelist.txt", index=False)

# %%
# !yes| bash vidCreate.sh
# Out:
# --2016-12-12 08:48:53--  http://mobile311.sfgov.org/media/san_francisco/report/photos/584b2dcb3da19793c74c6b3c/photo_20161209_141838.jpg
# Resolving mobile311.sfgov.org (mobile311.sfgov.org)... 54.144.250.241
# Connecting to mobile311.sfgov.org (mobile311.sfgov.org)|54.144.250.241|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 182710 (178K) [image/jpeg]
# Saving to: 'photo_20161209_141838.jpg'
#
# photo_20161209_1418 100%[===================>] 178.43K   920KB/s    in 0.2s
#
# 2016-12-12 08:48:53 (920 KB/s) - 'photo_20161209_141838.jpg' saved [182710/182710]
#
# --2016-12-12 08:48:53--  http://mobile311.sfgov.org/media/san_francisco/report/photos/5849eedd3da19793c74c4e09/IMAG1420_1_.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 197500 (193K) [image/jpeg]
# Saving to: 'IMAG1420_1_.jpg'
#
# IMAG1420_1_.jpg     100%[===================>] 192.87K  --.-KB/s    in 0.04s
#
# 2016-12-12 08:48:53 (4.70 MB/s) - 'IMAG1420_1_.jpg' saved [197500/197500]
#
# --2016-12-12 08:48:53--  http://mobile311.sfgov.org/media/san_francisco/report/photos/58485b9b3da19793c74c27e4/report.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 271215 (265K) [image/jpeg]
# Saving to: 'report.jpg'
#
# report.jpg          100%[===================>] 264.86K  --.-KB/s    in 0.04s
#
# 2016-12-12 08:48:53 (6.54 MB/s) - 'report.jpg' saved [271215/271215]
#
# --2016-12-12 08:48:53--  http://mobile311.sfgov.org/media/san_francisco/report/photos/5846e6f53da19793c74bef7f/photo_20161206_082645.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 95155 (93K) [image/jpeg]
# Saving to: 'photo_20161206_082645.jpg'
#
# photo_20161206_0826 100%[===================>]  92.92K  --.-KB/s    in 0.001s
#
# 2016-12-12 08:48:53 (125 MB/s) - 'photo_20161206_082645.jpg' saved [95155/95155]
#
# --2016-12-12 08:48:53--  http://mobile311.sfgov.org/media/san_francisco/report/photos/5846d9cd3da19793c74beca2/IMG_1624.JPG
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 328353 (321K) [image/jpeg]
# Saving to: 'IMG_1624.JPG'
#
# IMG_1624.JPG        100%[===================>] 320.66K  --.-KB/s    in 0.04s
#
# 2016-12-12 08:48:53 (8.00 MB/s) - 'IMG_1624.JPG' saved [328353/328353]
#
# --2016-12-12 08:48:53--  http://mobile311.sfgov.org/media/san_francisco/report/photos/5844b3de3da19793c74baa88/report.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 276187 (270K) [image/jpeg]
# Saving to: 'report.jpg.1'
#
# report.jpg.1        100%[===================>] 269.71K  --.-KB/s    in 0.001s
#
# 2016-12-12 08:48:53 (287 MB/s) - 'report.jpg.1' saved [276187/276187]
#
# --2016-12-12 08:48:53--  http://mobile311.sfgov.org/media/san_francisco/report/photos/584494013da19793c74ba596/photo_20161204_140903.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 65100 (64K) [image/jpeg]
# Saving to: 'photo_20161204_140903.jpg'
#
# photo_20161204_1409 100%[===================>]  63.57K  --.-KB/s    in 0s
#
# 2016-12-12 08:48:53 (486 MB/s) - 'photo_20161204_140903.jpg' saved [65100/65100]
#
# --2016-12-12 08:48:53--  http://mobile311.sfgov.org/media/san_francisco/report/photos/584373593da19793c74b9218/report.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 180791 (177K) [image/jpeg]
# Saving to: 'report.jpg.2'
#
# report.jpg.2        100%[===================>] 176.55K  --.-KB/s    in 0.001s
#
# 2016-12-12 08:48:54 (172 MB/s) - 'report.jpg.2' saved [180791/180791]
#
# --2016-12-12 08:48:54--  http://mobile311.sfgov.org/media/san_francisco/report/photos/5840ee343da18eff3daafe17/report.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 129222 (126K) [image/jpeg]
# Saving to: 'report.jpg.3'
#
# report.jpg.3        100%[===================>] 126.19K  --.-KB/s    in 0.001s
#
# 2016-12-12 08:48:54 (216 MB/s) - 'report.jpg.3' saved [129222/129222]
#
# --2016-12-12 08:48:54--  http://mobile311.sfgov.org/media/san_francisco/report/photos/5840c2ec3da18eff3daafa77/photo_20161201_164006.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 16766 (16K) [image/jpeg]
# Saving to: 'photo_20161201_164006.jpg'
#
# photo_20161201_1640 100%[===================>]  16.37K  --.-KB/s    in 0s
#
# 2016-12-12 08:48:54 (176 MB/s) - 'photo_20161201_164006.jpg' saved [16766/16766]
#
# --2016-12-12 08:48:54--  http://mobile311.sfgov.org/media/san_francisco/report/photos/5840400a3da18eff3daadd7b/report.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 179046 (175K) [image/jpeg]
# Saving to: 'report.jpg.4'
#
# report.jpg.4        100%[===================>] 174.85K  --.-KB/s    in 0.002s
#
# 2016-12-12 08:48:54 (95.3 MB/s) - 'report.jpg.4' saved [179046/179046]
#
# --2016-12-12 08:48:54--  http://mobile311.sfgov.org/media/san_francisco/report/photos/58403a353da18eff3daadbfb/photo_20161201_065644.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 62310 (61K) [image/jpeg]
# Saving to: 'photo_20161201_065644.jpg'
#
# photo_20161201_0656 100%[===================>]  60.85K  --.-KB/s    in 0s
#
# 2016-12-12 08:48:54 (316 MB/s) - 'photo_20161201_065644.jpg' saved [62310/62310]
#
# --2016-12-12 08:48:54--  http://mobile311.sfgov.org/media/san_francisco/report/photos/584035293da18eff3daadb81/1480602902016.jpg
# Reusing existing connection to mobile311.sfgov.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 87352 (85K) [image/jpeg]
# Saving to: '1480602902016.jpg'
#
# 1480602902016.jpg   100%[===================>]  85.30K  --.-KB/s    in 0s
#
# 2016-12-12 08:48:54 (447 MB/s) - '1480602902016.jpg' saved [87352/87352]
#
# FINISHED --2016-12-12 08:48:54--
# Total wall clock time: 1.1s
# Downloaded: 13 files, 2.0M in 0.3s (6.21 MB/s)
# ffmpeg version 2.8.8-0ubuntu0.16.04.1 Copyright (c) 2000-2016 the FFmpeg developers
#   built with gcc 5.4.0 (Ubuntu 5.4.0-6ubuntu1~16.04.2) 20160609
#   configuration: --prefix=/usr --extra-version=0ubuntu0.16.04.1 --build-suffix=-ffmpeg --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --cc=cc --cxx=g++ --enable-gpl --enable-shared --disable-stripping --disable-decoder=libopenjpeg --disable-decoder=libschroedinger --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmodplug --enable-libmp3lame --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librtmp --enable-libschroedinger --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxvid --enable-libzvbi --enable-openal --enable-opengl --enable-x11grab --enable-libdc1394 --enable-libiec61883 --enable-libzmq --enable-frei0r --enable-libx264 --enable-libopencv
#   libavutil      54. 31.100 / 54. 31.100
#   libavcodec     56. 60.100 / 56. 60.100
#   libavformat    56. 40.101 / 56. 40.101
#   libavdevice    56.  4.100 / 56.  4.100
#   libavfilter     5. 40.101 /  5. 40.101
#   libavresample   2.  1.  0 /  2.  1.  0
#   libswscale      3.  1.101 /  3.  1.101
#   libswresample   1.  2.101 /  1.  2.101
#   libpostproc    53.  3.100 / 53.  3.100
# [mjpeg @ 0x1076de0] Changeing bps to 8
# Input #0, image2, from '%04d.jpg':
#   Duration: 00:00:13.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 919x920 [SAR 1:1 DAR 919:920], 1 fps, 1 tbr, 1 tbn, 1 tbc
# File '../video.gif' already exists. Overwrite ? [y/N] [swscaler @ 0x109d780] deprecated pixel format used, make sure you did set range correctly
# Output #0, gif, to '../video.gif':
#   Metadata:
#     encoder         : Lavf56.40.101
#     Stream #0:0: Video: gif, bgr8, 919x920 [SAR 1:1 DAR 919:920], q=2-31, 200 kb/s, 1 fps, 100 tbn, 1 tbc
#     Metadata:
#       encoder         : Lavc56.60.100 gif
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> gif (native))
# Press [q] to stop, [?] for help
# Input stream #0:0 frame changed from size:919x920 fmt:yuvj420p to size:1536x864 fmt:yuvj420p
# [swscaler @ 0x1102920] deprecated pixel format used, make sure you did set range correctly
# Input stream #0:0 frame changed from size:1536x864 fmt:yuvj420p to size:1536x1152 fmt:yuvj420p
# [swscaler @ 0x1102920] deprecated pixel format used, make sure you did set range correctly
# Input stream #0:0 frame changed from size:1536x1152 fmt:yuvj420p to size:864x1536 fmt:yuvj420p
# [swscaler @ 0x108f3e0] deprecated pixel format used, make sure you did set range correctly
# Input stream #0:0 frame changed from size:864x1536 fmt:yuvj420p to size:512x289 fmt:yuvj420p
# [swscaler @ 0x108ce60] deprecated pixel format used, make sure you did set range correctly
# Input stream #0:0 frame changed from size:512x289 fmt:yuvj420p to size:864x1536 fmt:yuvj420p
# [swscaler @ 0x1102920] deprecated pixel format used, make sure you did set range correctly
# Input stream #0:0 frame changed from size:864x1536 fmt:yuvj420p to size:1536x1152 fmt:yuvj420p
# [swscaler @ 0x10d4620] deprecated pixel format used, make sure you did set range correctly
# Input stream #0:0 frame changed from size:1536x1152 fmt:yuvj420p to size:1152x1536 fmt:yuvj420p
# [swscaler @ 0x10d4620] deprecated pixel format used, make sure you did set range correctly
# frame=   13 fps=0.0 q=-0.0 Lsize=    4540kB time=00:00:13.00 bitrate=2861.1kbits/s
# video:4539kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.019469%
# ffmpeg version 2.8.8-0ubuntu0.16.04.1 Copyright (c) 2000-2016 the FFmpeg developers
#   built with gcc 5.4.0 (Ubuntu 5.4.0-6ubuntu1~16.04.2) 20160609
#   configuration: --prefix=/usr --extra-version=0ubuntu0.16.04.1 --build-suffix=-ffmpeg --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --cc=cc --cxx=g++ --enable-gpl --enable-shared --disable-stripping --disable-decoder=libopenjpeg --disable-decoder=libschroedinger --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmodplug --enable-libmp3lame --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librtmp --enable-libschroedinger --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxvid --enable-libzvbi --enable-openal --enable-opengl --enable-x11grab --enable-libdc1394 --enable-libiec61883 --enable-libzmq --enable-frei0r --enable-libx264 --enable-libopencv
#   libavutil      54. 31.100 / 54. 31.100
#   libavcodec     56. 60.100 / 56. 60.100
#   libavformat    56. 40.101 / 56. 40.101
#   libavdevice    56.  4.100 / 56.  4.100
#   libavfilter     5. 40.101 /  5. 40.101
#   libavresample   2.  1.  0 /  2.  1.  0
#   libswscale      3.  1.101 /  3.  1.101
#   libswresample   1.  2.101 /  1.  2.101
#   libpostproc    53.  3.100 / 53.  3.100
# [mjpeg @ 0x1d69de0] Changeing bps to 8
# Input #0, image2, from '%04d.jpg':
#   Duration: 00:00:13.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 919x920 [SAR 1:1 DAR 919:920], 1 fps, 1 tbr, 1 tbn, 1 tbc
# File '../video.webm' already exists. Overwrite ? [y/N] Not overwriting - exiting
# yes: standard output: Broken pipe

# %%
'''
Had problems with this code, running standalone

# %cd assets/
# !wget -i ../imagelist.txt

# !sleep 30
#%ls | gawk 'BEGIN{ a=1 }{ printf "mv \"%s\" %04d.jpg\n", $0, a++ }' | bash
#!sleep 10
#!convert -delay 50 *.jpg out.mp4
# %cd ..
'''
# Out:
# '\nHad problems with this code, running standalone\n\n%cd assets/\n!wget -i ../imagelist.txt\n\n!sleep 30\n#%ls | gawk \'BEGIN{ a=1 }{ printf "mv "%s" %04d.jpg\n", $0, a++ }\' | bash\n#!sleep 10\n#!convert -delay 50 *.jpg out.mp4\n%cd ..\n'

# %%
#!convert -delay 50 *.jpg out.mp4

# %%
# !ls
# Out:
# San+Francisco+Concerns-Homeless Aggressive behavior and well being.ipynb
# San+Francisco+Homeless Encampments.ipynb
# San+Francisco+Homeless+Data+Analysis (1).ipynb
# San+Francisco+Homeless+Data+Analysis.ipynb
# San+Francisco+Poop.ipynb
# assets
# gifCreate.sh
# gistfile1.txt
# imagelist.txt
# input
# sfOneDay.ipynb
# vidCreate.sh
# video.gif
# video.webm

# %%
Image('report2.jpg')
