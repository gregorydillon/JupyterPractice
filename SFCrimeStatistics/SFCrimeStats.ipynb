# %%
import numpy as np
import pandas as pd

# %%
url = 'https://data.sfgov.org/resource/ymzp-3rnj.csv'
limit = '?$limit=50000'
#https://soda.demo.socrata.com/resource/4tka-6guv.json?$order=magnitude DESC
#order = '&$order=IncidntNum'
url = url+limit
url
# Out:
# 'https://data.sfgov.org/resource/ymzp-3rnj.csv?$limit=50000'

# %%
df=pd.read_csv(url)

# %%
df.head(500)
# Out:
#      IncidntNum                Category  \
# 0     160952286           VEHICLE THEFT
# 1     160950014       RECOVERED VEHICLE
# 2     160949998                 ASSAULT
# 3     160950161           LARCENY/THEFT
# 4     160949982                 ROBBERY
# 5     160949976                 ROBBERY
# 6     160949976          OTHER OFFENSES
# 7     160950058           DRUG/NARCOTIC
# 8     160950058                WARRANTS
# 9     160949960                 ASSAULT
# 10    166275303           LARCENY/THEFT
# 11    160949904          OTHER OFFENSES
# 12    160951266                BURGLARY
# 13    160952189            NON-CRIMINAL
# 14    166275284           LARCENY/THEFT
# 15    160949885            NON-CRIMINAL
# 16    160949835           LARCENY/THEFT
# 17    160949807                 ROBBERY
# 18    160950105  SEX OFFENSES, FORCIBLE
# 19    160950105              KIDNAPPING
# 20    160949788            NON-CRIMINAL
# 21    166276339           LARCENY/THEFT
# ...

# %%
len(df)
# Out:
# 50000

# %%
homeless cad number  163382203
