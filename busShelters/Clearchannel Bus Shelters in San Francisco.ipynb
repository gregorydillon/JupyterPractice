# %%
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
df = pd.read_csv('https://data.sfgov.org/resource/af6r-k7g6.csv')

# %% [markdown]
# ### save dataframe to disk
# df.to_csv('BusShelter.csv', encoding = 'utf-8')

# %%
df.head()
# Out:
#     CaseID                  Opened Closed                 Updated Status  \
# 0  6565967  11/25/2016 06:39:30 PM    NaN  11/25/2016 06:40:41 PM   Open
# 1  6565960  11/25/2016 06:29:16 PM    NaN  11/25/2016 06:30:58 PM   Open
# 2  6565311  11/25/2016 04:00:15 PM    NaN  11/25/2016 04:00:15 PM   Open
# 3  6565263  11/25/2016 03:46:55 PM    NaN  11/25/2016 03:46:55 PM   Open
# 4  6565127  11/25/2016 03:09:56 PM    NaN  11/25/2016 03:09:56 PM   Open
#
#   Status Notes             Responsible Agency                  Category  \
# 0         Open  Clear Channel - Transit Queue          Damaged Property
# 1         Open  Clear Channel - Transit Queue          Damaged Property
# 2         Open  Clear Channel - Transit Queue  Graffiti Public Property
# 3         Open  Clear Channel - Transit Queue  Graffiti Public Property
# 4         Open  Clear Channel - Transit Queue  Graffiti Public Property
#
#                                  Request Type  \
# ...

# %%
df.Neighborhood.value_counts()
# Out:
# Mission                         113
# South of Market                  99
# Outer Richmond                   89
# Civic Center                     57
# Mission Dolores                  54
# Duboce Triangle                  47
# Tenderloin                       41
# Chinatown                        25
# Dolores Heights                  23
# Mission Bay                      22
# West Portal                      18
# Downtown / Union Square          15
# Inner Richmond                   14
# Outer Sunset                     13
# Lower Haight                     13
# Golden Gate Park                 12
# Alamo Square                     11
# Polk Gulch                       11
# Inner Sunset                     11
# Portola                          11
# Financial District               10
# Dogpatch                         10
# Western Addition                  9
# Bayview                           9
# Glen Park                         9
# Excelsior                         8
# ...

# %%
df['Supervisor District'].value_counts()
# Out:
# 6.0     223
# 8.0     156
# 1.0     118
# 9.0     114
# 5.0      95
# 3.0      78
# 10.0     77
# 7.0      56
# 11.0     23
# 4.0      23
# 2.0      21
# 0.0       2
# Name: Supervisor District, dtype: int64

# %%
df['Request Type'].value_counts()
# Out:
# Not_Offensive Graffiti on Public Property       359
# Transit_shelter_platform                        246
# Offensive Graffiti on Public Property           109
# Damaged Transit_Shelter_Platform                104
# Damaged Transit_Shelter_Platform_Hazardous       89
# General Cleaning                                 53
# Damaged Transit_Shelter_Ad_Kiosk                 22
# Hazardous Materials                               7
# Not_Offensive Graffiti on Private Property        2
# Damaged_Property                                  1
# Offensive Graffiti on Private Property            1
# Illegal Postings - Affixed_Improperly             1
# Park - Structural_Maintenance                     1
# MUNI - Services_Service_Delivery_Facilities       1
# MUNI  - Services_Service_Delivery_Facilities      1
# Sign - Incorrect_Signage                          1
# Damaged Kiosk_Public_Toilet                       1
# Damaged News_Rack                                 1
# ...

# %%
df.Source.value_counts()
# Out:
# Open311              625
# Voice In             271
# Web Self Service      54
# Integrated Agency     35
# Twitter               15
# Name: Source, dtype: int64

# %%
df.Source.describe()
# Out:
# count        1000
# unique          5
# top       Open311
# freq          625
# Name: Source, dtype: object

# %%
df['Request Type'].describe()
# Out:
# count                                          1000
# unique                                           18
# top       Not_Offensive Graffiti on Public Property
# freq                                            359
# Name: Request Type, dtype: object

# %%
df['Opened'].unique()
# Out:
# array(['11/25/2016 06:39:30 PM', '11/25/2016 06:29:16 PM',
#        '11/25/2016 04:00:15 PM', '11/25/2016 03:46:55 PM',
#        '11/25/2016 03:09:56 PM', '11/25/2016 02:49:17 PM',
#        '11/25/2016 02:46:31 PM', '11/25/2016 12:32:44 PM',
#        '11/25/2016 10:51:11 AM', '11/25/2016 09:44:53 AM',
#        '11/25/2016 09:18:51 AM', '11/25/2016 08:36:51 AM',
#        '11/25/2016 03:44:50 AM', '11/25/2016 03:43:24 AM',
#        '11/25/2016 03:42:47 AM', '11/24/2016 11:29:46 PM',
#        '11/24/2016 05:17:59 PM', '11/24/2016 02:17:55 PM',
#        '11/24/2016 01:48:06 PM', '11/24/2016 01:37:33 PM',
#        '11/24/2016 01:07:33 PM', '11/24/2016 11:46:36 AM',
#        '11/24/2016 10:49:13 AM', '11/24/2016 08:42:38 AM',
#        '11/23/2016 09:20:22 PM', '11/23/2016 07:50:06 PM',
#        '11/23/2016 02:39:29 PM', '11/23/2016 02:35:12 PM',
#        '11/23/2016 01:59:43 PM', '11/23/2016 12:43:12 PM',
#        '11/23/2016 11:11:48 AM', '11/23/2016 10:18:15 AM',
# ...

# %%
df.Source.argmax
# Out:
# <bound method Series.idxmax of 0               Voice In
# 1               Voice In
# 2                Open311
# 3                Open311
# 4                Open311
# 5               Voice In
# 6               Voice In
# 7                Open311
# 8                Open311
# 9                Open311
# 10              Voice In
# 11               Open311
# 12               Open311
# 13               Open311
# 14               Open311
# 15               Open311
# 16               Open311
# 17      Web Self Service
# 18               Open311
# 19              Voice In
# 20     Integrated Agency
# 21              Voice In
# 22               Open311
# 23               Open311
# 24              Voice In
# 25               Open311
# 26              Voice In
# 27               Open311
# 28              Voice In
# 29      Web Self Service
#              ...
# 970             Voice In
# 971              Open311
# 972              Open311
# 973              Open311
# 974              Open311
# ...

# %%
df['Neighborhood'].value_counts()
# Out:
# Mission                         113
# South of Market                  99
# Outer Richmond                   89
# Civic Center                     57
# Mission Dolores                  54
# Duboce Triangle                  47
# Tenderloin                       41
# Chinatown                        25
# Dolores Heights                  23
# Mission Bay                      22
# West Portal                      18
# Downtown / Union Square          15
# Inner Richmond                   14
# Outer Sunset                     13
# Lower Haight                     13
# Golden Gate Park                 12
# Alamo Square                     11
# Polk Gulch                       11
# Inner Sunset                     11
# Portola                          11
# Financial District               10
# Dogpatch                         10
# Western Addition                  9
# Bayview                           9
# Glen Park                         9
# Excelsior                         8
# ...

# %% [markdown]
# ### Create a dataframe with just the rows with mediaURL

# %%
df.head()
# Out:
#     CaseID                  Opened Closed                 Updated Status  \
# 0  6565967  11/25/2016 06:39:30 PM    NaN  11/25/2016 06:40:41 PM   Open
# 1  6565960  11/25/2016 06:29:16 PM    NaN  11/25/2016 06:30:58 PM   Open
# 2  6565311  11/25/2016 04:00:15 PM    NaN  11/25/2016 04:00:15 PM   Open
# 3  6565263  11/25/2016 03:46:55 PM    NaN  11/25/2016 03:46:55 PM   Open
# 4  6565127  11/25/2016 03:09:56 PM    NaN  11/25/2016 03:09:56 PM   Open
#
#   Status Notes             Responsible Agency                  Category  \
# 0         Open  Clear Channel - Transit Queue          Damaged Property
# 1         Open  Clear Channel - Transit Queue          Damaged Property
# 2         Open  Clear Channel - Transit Queue  Graffiti Public Property
# 3         Open  Clear Channel - Transit Queue  Graffiti Public Property
# 4         Open  Clear Channel - Transit Queue  Graffiti Public Property
#
#                                  Request Type  \
# ...

# %% [markdown]
# ### This has interest as What happens when a lot are closed at the same minute
#
# http://stackoverflow.com/questions/16852911/how-do-i-convert-dates-in-a-pandas-data-frame-to-a-date-data-type

# %% [markdown]
# ![title](img/picture.png)

# %%
    df['Closed'].value_counts()
# Out:
# 11/16/2016 10:30:31 AM    11
# 10/28/2016 04:30:54 PM    11
# 10/28/2016 04:30:56 PM    10
# 11/16/2016 10:30:23 AM    10
# 10/28/2016 04:30:55 PM     6
# 11/16/2016 10:30:30 AM     5
# 11/16/2016 10:30:14 AM     4
# 11/16/2016 10:30:34 AM     4
# 11/16/2016 10:30:32 AM     3
# 11/16/2016 10:30:20 AM     3
# 11/16/2016 10:30:24 AM     2
# 11/16/2016 10:30:29 AM     2
# 11/16/2016 10:30:26 AM     2
# 11/16/2016 10:30:17 AM     2
# 11/16/2016 10:30:27 AM     2
# 10/28/2016 06:51:38 AM     1
# 11/09/2016 12:13:41 PM     1
# 11/02/2016 05:47:57 AM     1
# 11/16/2016 10:30:33 AM     1
# 11/08/2016 11:59:27 AM     1
# 11/02/2016 05:51:50 AM     1
# 10/27/2016 12:32:36 PM     1
# 11/03/2016 01:01:10 PM     1
# 11/07/2016 06:54:09 AM     1
# 11/07/2016 05:45:28 AM     1
# 11/10/2016 08:34:32 AM     1
# 11/03/2016 01:04:48 PM     1
# 10/26/2016 11:57:34 AM     1
# 11/17/2016 05:37:18 AM     1
# 10/31/2016 08:56:53 AM     1
#                           ..
# 11/08/2016 05:26:37 AM     1
# ...

# %%
df.columns
# Out:
# Index(['CaseID', 'Opened', 'Closed', 'Updated', 'Status', 'Status Notes',
#        'Responsible Agency', 'Category', 'Request Type', 'Request Details',
#        'Address', 'Supervisor District', 'Neighborhood', 'Point', 'Source',
#        'Media URL'],
#       dtype='object')

# %%
mydf = df[['CaseID', 'Status', 'Status Notes',
            'Category', 'Request Type', 'Request Details',
           'Address', 'Neighborhood',  'Source']]

# %%
mydf.head()
# Out:
#     CaseID Status Status Notes                  Category  \
# 0  6565967   Open         Open          Damaged Property
# 1  6565960   Open         Open          Damaged Property
# 2  6565311   Open         Open  Graffiti Public Property
# 3  6565263   Open         Open  Graffiti Public Property
# 4  6565127   Open         Open  Graffiti Public Property
#
#                                  Request Type  \
# 0            Damaged Transit_Shelter_Platform
# 1  Damaged Transit_Shelter_Platform_Hazardous
# 2       Offensive Graffiti on Public Property
# 3   Not_Offensive Graffiti on Public Property
# 4   Not_Offensive Graffiti on Public Property
#
#                             Request Details  \
# 0                  Transit_Shelter_Platform
# 1        Transit_Shelter_Platform_Hazardous
# 2      Transit_Shelter_Platform - Offensive
# 3  Transit_Shelter_Platform - Not_Offensive
# 4  Transit_Shelter_Platform - Not_Offensive
#
# ...

# %%
mydf.Neighborhood.describe
# Out:
# <bound method NDFrame.describe of 0                Cathedral Hill
# 1               South of Market
# 2                  Inner Sunset
# 3                    Stonestown
# 4                      Dogpatch
# 5      Aquatic Park / Ft. Mason
# 6               South of Market
# 7                     Glen Park
# 8                  Inner Sunset
# 9       Downtown / Union Square
# 10              Duboce Triangle
# 11                 Civic Center
# 12               Outer Richmond
# 13               Outer Richmond
# 14               Outer Richmond
# 15              South of Market
# 16                   Polk Gulch
# 17                  West Portal
# 18            Parnassus Heights
# 19              Duboce Triangle
# 20                 Civic Center
# 21                       Marina
# 22                 Civic Center
# 23             Golden Gate Park
# 24                    Ingleside
# 25                      Mission
# 26                     Nob Hill
# 27                    Chinatown
# ...

# %%
mydf.loc[:11]
# Out:
#      CaseID Status Status Notes                      Category  \
# 0   6565967   Open         Open              Damaged Property
# 1   6565960   Open         Open              Damaged Property
# 2   6565311   Open         Open      Graffiti Public Property
# 3   6565263   Open         Open      Graffiti Public Property
# 4   6565127   Open         Open      Graffiti Public Property
# 5   6565062   Open         Open  Street and Sidewalk Cleaning
# 6   6565053   Open         Open              Damaged Property
# 7   6564641   Open         Open      Graffiti Public Property
# 8   6564347   Open         Open      Graffiti Public Property
# 9   6564168   Open         Open              Damaged Property
# 10  6564088   Open         Open  Street and Sidewalk Cleaning
# 11  6563970   Open         Open      Graffiti Public Property
#
#                                   Request Type  \
# 0             Damaged Transit_Shelter_Platform
# 1   Damaged Transit_Shelter_Platform_Hazardous
# ...

# %%
df.concat([1,2,3],)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-b6fbc9521ff1> in <module>()
# ----> 1 df.concat([1,2,3],)
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
from ipyleaflet import Map

Map(center=[34.6252978589571, -77.34580993652344], zoom=10)

# %%
df['Neighborhood'].sort_values().head()
# Out:
# 276    Alamo Square
# 423    Alamo Square
# 411    Alamo Square
# 965    Alamo Square
# 403    Alamo Square
# Name: Neighborhood, dtype: object

# %%
df.sort_values('Neighborhood').head()
# Out:
#       CaseID                  Opened                  Closed  \
# 276  6527981  11/14/2016 08:07:27 AM  11/14/2016 11:05:59 AM
# 423  6512320  11/09/2016 06:05:13 AM  11/09/2016 06:18:47 AM
# 411  6512992  11/09/2016 09:16:26 AM  11/09/2016 12:14:58 PM
# 965  6453400  10/24/2016 07:58:26 AM  10/28/2016 04:30:57 PM
# 403  6513987  11/09/2016 12:07:38 PM  11/09/2016 12:18:50 PM
#
#                     Updated  Status  \
# 276  11/14/2016 11:05:59 AM  Closed
# 423  11/09/2016 06:18:47 AM  Closed
# 411  11/09/2016 12:14:58 PM  Closed
# 965  10/28/2016 04:30:57 PM  Closed
# 403  11/09/2016 12:18:50 PM  Closed
#
#                                    Status Notes  \
# 276                                 Scheduled -
# 423                       Case is a Duplicate -
# 411                                 Scheduled -
# 965  Resolved per Clear Channel - Admin Closure
# 403                       Case is a Duplicate -
#
#                 Responsible Agency                      Category  \
# ...

# %%
df.groupby('Neighborhood').value_counts('Closed')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-14d7b5183daf> in <module>()
# ----> 1 df.groupby('Neighborhood').value_counts('Closed')
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/groupby.py in __getattr__(self, attr)
#     496
#     497         raise AttributeError("%r object has no attribute %r" %
# --> 498                              (type(self).__name__, attr))
#     499
#     500     plot = property(GroupByPlot)
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'value_counts'

# %%
df.Closed.value_counts().head()
# Out:
# 11/16/2016 10:30:31 AM    11
# 10/28/2016 04:30:54 PM    11
# 10/28/2016 04:30:56 PM    10
# 11/16/2016 10:30:23 AM    10
# 10/28/2016 04:30:55 PM     6
# Name: Closed, dtype: int64

# %%
df.Neighborhood.value_counts()
# Out:
# Mission                         113
# South of Market                  99
# Outer Richmond                   89
# Civic Center                     57
# Mission Dolores                  54
# Duboce Triangle                  47
# Tenderloin                       41
# Chinatown                        25
# Dolores Heights                  23
# Mission Bay                      22
# West Portal                      18
# Downtown / Union Square          15
# Inner Richmond                   14
# Outer Sunset                     13
# Lower Haight                     13
# Golden Gate Park                 12
# Alamo Square                     11
# Polk Gulch                       11
# Inner Sunset                     11
# Portola                          11
# Financial District               10
# Dogpatch                         10
# Western Addition                  9
# Bayview                           9
# Glen Park                         9
# Excelsior                         8
# ...

# %%
df['Address'].value_counts()
# Out:
# Intersection of 18TH ST and CHURCH ST                25
# Intersection of 18TH ST and MISSION ST               16
# Not associated with a specific address               16
# 3803 18TH ST, SAN FRANCISCO, CA, 94114               12
# Intersection of CHURCH ST and DUBOCE AVE             12
# Intersection of 20TH ST and MISSION ST               12
# Intersection of 16TH ST and DOLORES ST               11
# Intersection of CORDELIA ST and                       8
# Intersection of 18TH ST and VALENCIA ST               8
# Intersection of 4TH ST and KING ST                    8
# 6901 GEARY BLVD, SAN FRANCISCO, CA, 94121             8
# Intersection of 33RD AVE and GEARY BLVD               7
# Intersection of 4TH ST and BERRY ST                   7
# 7501 GEARY BLVD, SAN FRANCISCO, CA, 94121             7
# Intersection of 8TH ST and MISSION ST                 7
# Intersection of ULLOA ST and WEST PORTAL AVE          7
# 1182 MARKET ST, SAN FRANCISCO, CA, 94102              6
# ...
